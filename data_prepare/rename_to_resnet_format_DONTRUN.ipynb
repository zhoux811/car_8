# %%
#implode files in 'classes' folders
import os
import re, shutil, tqdm
from os import listdir, mkdir
from os.path import isfile, join, isdir

workingDirName = r'../Car_12class_raw'
listdir(workingDirName)
# Out:
# ['honda_accord_08_12',
#  'honda_civic_06_11',
#  'honda_civ_13_15',
#  'honda_civ_16_21',
#  'honda_crv_12_16',
#  'honda_crv_17_21',
#  'hyundai_sonata_11_14',
#  'hyundai_sonata_15_17',
#  'hyundai_sonata_18_19',
#  'hyundai_sonata_20_21',
#  'toyota_prius_10_15',
#  'toyota_prius_16_21']

# %%
for folderName in listdir(workingDirName):
    print(folderName)
    for f in tqdm.tqdm(listdir(join(workingDirName, folderName))):
        print(f)
        pass
        
        os.rename(join(workingDirName, folderName, f),join(workingDirName, folderName, folderName+'_'+f))
# Out:
# honda_accord_08_12
#  17%|████████████▋                                                              | 476/2812 [00:00<00:00, 4721.89it/s]
# 0.jpg
# 1.jpg
# 100.jpg
# 1000.jpg
# 1001.jpg
# 1002.jpg
# 1003.jpg
# 1004.jpg
# 1005.jpg
# 1006.jpg
# 1007.jpg
# 1008.jpg
# 1009.jpg
# 1010.jpg
# 1011.jpg
# 1012.jpg
# 1013.jpg
# 1014.jpg
# 1015.jpg
# 1016.jpg
# 1017.jpg
# 1018.jpg
# 1019.jpg
# 1020.jpg
# 1021.jpg
# 1022.jpg
# 1023.jpg
# 1024.jpg
# 1025.jpg
# 1026.jpg
# 1027.jpg
# 1028.jpg
# 1029.jpg
# 1030.jpg
# 1031.jpg
# 1032.jpg
# 1033.jpg
# 1034.jpg
# 1035.jpg
# 1036.jpg
# 1037.jpg
# 1038.jpg
# 1039.jpg
# 104.jpg
# 1040.jpg
# 1041.jpg
# 1042.jpg
# 1043.jpg
# 1044.jpg
# 1045.jpg
# 1046.jpg
# 1047.jpg
# 1048.jpg
# 1049.jpg
# 105.jpg
# 1050.jpg
# 1051.jpg
# 1052.jpg
# 1053.jpg
# 1054.jpg
# 1055.jpg
# 1056.jpg
# 1057.jpg
# 1058.jpg
# 1059.jpg
# 106.jpg
# 1060.jpg
# 1061.jpg
# 1062.jpg
# 1063.jpg
# 1064.jpg
# 1065.jpg
# 1066.jpg
# 1067.jpg
# 1068.jpg
# 1069.jpg
# 1070.jpg
# 1071.jpg
# 1072.jpg
# ...
